# %%
from scipy import io
import matplotlib.pyplot as plt
import numpy as np
import os
# 36 rows of 6-tuples
data_dir = 'C:\\Users\\xieji\\iCloudDrive\\Documents\\Data\\gym-hand-sim'
NERData = io.loadmat(os.path.join(data_dir, 'NERData.mat'))['resultsmat'][0]

# %%
rmses = []

fs = 100
for trial_num in range(NERData.shape[0]):
    if NERData[trial_num][3] == 'Dynamic':
        with open(os.path.join(data_dir, 'simangles{}.npy'.format(trial_num)), 'rb') as f:
            angles = np.load(f)
            angles = np.reshape(angles, (angles.size,1))
        target = np.radians(NERData[trial_num][2])
        plt.figure(figsize=(10,10), facecolor=(1, 1, 1))
        
        plt.plot(np.linspace(0,target.size/fs,target.size), 180*target / np.pi, label='Target Angle', color='g')
        plt.plot(np.linspace(0,target.size/fs,target.size), -180 * angles / np.pi, label='Measured Angle', color='r')
        
        plt.title('', fontsize=18, fontweight='bold', pad=50)
        plt.xlabel('Time (seconds)', fontsize=30, fontweight='bold', labelpad=15)
        plt.ylabel('Angle (degrees)', fontsize=30, fontweight='bold', labelpad=10)
        plt.xticks(fontsize=20)
        plt.yticks(fontsize=20)
        plt.legend(loc='upper right', fontsize=25)
        plt.ylim(-1.6 * 180 / np.pi, 0.5 * 180 / np.pi)
        rmses.append(np.sqrt(np.mean((-180 * angles / np.pi-180 * target / np.pi)**2)))
        
print(np.mean(rmses))
# Out:
# 2.5535633803367506

# %%
rmses_subject = [[],[],[]]

for trial_num in range(NERData.shape[0]):
    for subject in range(3):
        if (NERData[trial_num][5] == subject + 1 and NERData[trial_num][3] == 'Dynamic'):
            with open(os.path.join(data_dir, 'simangles{}.npy'.format(trial_num)), 'rb') as f:
                angles = np.load(f)
                angles = np.reshape(angles, (angles.size,1))
            target = np.radians(NERData[trial_num][2])

            rmses_subject[subject].append(np.sqrt(np.mean((-180 * angles / np.pi-180 * target / np.pi)**2)))
            
for subject in range(3):
    rmses_subject[subject] = np.mean(rmses_subject[subject])

labels = ['Subject1', 'Subject2', 'Subject3']

x = [1,2,3]
plt.figure(figsize=(25,25))
plt.bar(x, rmses_subject)
plt.xticks(x, labels=labels)
plt.title('Joint Angle RMSE in Three Participants', fontsize=30, fontweight='bold')
plt.ylabel('RMSE (Degrees)', fontsize=30, fontweight='bold', labelpad=15)
plt.xticks(fontsize=30, fontweight='bold')
plt.yticks(fontsize=20)
# Out:
# (array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. ]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
coins = [42.27997,
        32.16,
        22.28,
        24.8,
        22.42,
        26.82,
        40.06,
        62.53999,
        52.82,
        52.1]

coins2 = [18.79999,
        23.32001,
        23.64001,
        18.79999,
        11.59998,
        20.14001,
        11.59998,
        19.54004,
        10.88,
        17.33997]

plt.figure(figsize=(25,25))
bins = np.linspace(0, 60, 20)

plt.hist(coins, bins, alpha=0.5, label='Hand Tracking')
plt.hist(coins2, bins, alpha=0.5, label='Trigger Only')
plt.title('Task Completion Times for 3x Coin Pick and Place', fontsize=30, fontweight='bold')
plt.xlabel('Completion Time (Seconds)', fontsize=30, fontweight='bold', labelpad=15)
plt.ylabel('Count', fontsize=30, fontweight='bold', labelpad=15)
plt.xticks(np.linspace(0,60,13),fontsize=30)
plt.yticks(np.linspace(0,3,4), fontsize=30)
plt.legend(loc='upper right', fontsize=30)

# %%
boxes = [6,
        9,
        7,
        9,
        9,
        5,
        6,
        8,
        5,
        8]

boxes2 = [12,
        10,
        14,
        10,
        12,
        12,
        13,
        12,
        11,
        14,
        13]

plt.figure(figsize=(25,25))
bins = np.linspace(0, 20, 10)

plt.hist(boxes, bins, alpha=0.5, label='Hand Tracking')
plt.hist(boxes2, bins, alpha=0.5, label='Trigger Only')
plt.title('# Boxes Moved in 60 Seconds', fontsize=30, fontweight='bold')
plt.xlabel('# Boxes Moved', fontsize=30, fontweight='bold', labelpad=15)
plt.ylabel('Count', fontsize=30, fontweight='bold', labelpad=15)
plt.xticks(np.linspace(0,20,21),fontsize=30)
plt.yticks(fontsize=30)
plt.legend(loc='upper right', fontsize=30)

# %%
sphere = [3.380005,
    3.279999,
    2.860001,
    2.62001,
    2.479996,
    2.660004,
    3.060013,
    3.020004,
    3.039978,
         3]

sphere2 = [2.539999,
2.1,
1.919998,
2.319992,
2.360001,
1.959991,
2.179993,
2,
2.199982,
1.959991]

plt.figure(figsize=(25,25))
bins = np.linspace(0, 5, 20)

plt.hist(sphere, bins, alpha=0.5, label='Hand Tracking')
plt.hist(sphere2, bins, alpha=0.5, label='Trigger Only')
plt.title('Sphere Pick and Place Completion Times', fontsize=30, fontweight='bold')
plt.xlabel('Completion Time (Seconds)', fontsize=30, fontweight='bold', labelpad=15)
plt.ylabel('Count', fontsize=30, fontweight='bold', labelpad=15)
plt.xticks(np.linspace(0,5,11),fontsize=30)
plt.yticks(fontsize=30)
plt.legend(loc='upper right', fontsize=30)
