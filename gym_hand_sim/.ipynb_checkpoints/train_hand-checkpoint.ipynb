# %%
from scipy import io
import matplotlib.pyplot as plt
import numpy as np
import os
# 36 rows of 6-tuples
data_dir = 'C:\\Users\\xieji\\iCloudDrive\\Documents\\Data\\gym-hand-sim'
NERData = io.loadmat(os.path.join(data_dir, 'NERData.mat'))['resultsmat'][0]

# %%
rmses = []
for trial_num in range(NERData.shape[0]):
    if NERData[trial_num][3] == 'Dynamic':
        with open(os.path.join(data_dir, 'simangles{}.npy'.format(trial_num)), 'rb') as f:
            angles = np.load(f)
            angles = np.reshape(angles, (angles.size,1))
        target = np.radians(NERData[trial_num][2])
        plt.figure(figsize=(10,10), facecolor=(1, 1, 1))
        plt.plot(target, label='Target Angle')
        plt.plot(-angles, label='Measured Angle')
        plt.title('Command & Measured Finger Joint Angles Over 482 Data Samples', fontsize=18, fontweight='bold', pad=50)
        plt.xlabel('Datapoint', fontsize=14, fontweight='bold', labelpad=15)
        plt.ylabel('Angle (radians)', fontsize=14, fontweight='bold', labelpad=10)
        plt.legend(loc='upper right', fontsize=12)
        plt.ylim(-1.6, 0.5)
        rmses.append(np.sqrt(np.mean((-angles-target)**2)))
        
print(np.mean(rmses))
# Out:
# 0.04456808864523253

# %%
(-angles-target).shape
# Out:
# (482, 482)

# %%
# Out:
# range(0, 36)
